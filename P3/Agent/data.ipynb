# %%
import pandas as pd

# %%
# 1. 定义映射字典
label_dict = {
    '28-28': 0, '17-17-17': 1, '10-26-26': 2, 'DAP': 3, 
    '20-20': 4, '14-35-14': 5, 'Urea': 6
}

# %%
train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")

# %%
# 2. 特征工程：拼接、标签转化、Bool化
def export_processed_data(train_df, test_df):
    # 记录训练集长度
    train_len = len(train_df)
    
    # 提取并转化标签
    y_train = train_df['Fertilizer Name'].map(label_dict).astype(int)
    
    # 合并数据进行统一编码 (排除标签列)
    combined = pd.concat([
        train_df.drop(columns=['Fertilizer Name']), 
        test_df
    ], axis=0).reset_index(drop=True)
    
    # 拼接新特征
    combined['Soil_Crop'] = combined['Soil Type'].astype(str) + "_" + combined['Crop Type'].astype(str)
    
    # Bool化 (get_dummies 会自动移除被编码的 object 列)
    cat_cols = ['Soil Type', 'Crop Type', 'Soil_Crop']
    combined_encoded = pd.get_dummies(combined, columns=cat_cols, dtype=bool)
    
    # 拆分
    X_train = combined_encoded.iloc[:train_len].copy()
    X_test = combined_encoded.iloc[train_len:].copy()
    
    # 将标签并入 X_train，命名为 class
    X_train['class'] = y_train.values
    
    # 3. 输出为 CSV
    X_train.to_csv('X_train.csv', index=False)
    X_test.to_csv('X_test.csv', index=False)
    
    print("文件已成功输出：X_train.csv, X_test.csv")
    print(f"训练集形状: {X_train.shape}, 测试集形状: {X_test.shape}")

    return X_train, X_test

# 调用函数
X_train , X_test = export_processed_data(train, test)
# Out:
# 文件已成功输出：X_train.csv, X_test.csv
# 训练集形状: (750000, 79), 测试集形状: (250000, 78)

# %%
display(X_train.head())
# Out:
#    id  Temparature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0   0           37        70        36        36          4            5
# 1   1           27        69        65        30          6           18
# 2   2           29        63        32        24         12           16
# 3   3           35        62        54        39         12            4
# 4   4           35        58        43        37          2           16
#
#    Soil Type_Black  Soil Type_Clayey  Soil Type_Loamy  ...  \
# 0            False              True            False  ...
# 1            False             False            False  ...
# 2            False             False            False  ...
# 3            False             False            False  ...
# 4            False             False            False  ...
#
#    Soil_Crop_Sandy_Ground Nuts  Soil_Crop_Sandy_Maize  \
# 0                        False                  False
# 1                        False                  False
# 2                        False                  False
# 3                        False                  False
# 4                        False                  False
#
#    Soil_Crop_Sandy_Millets  Soil_Crop_Sandy_Oil seeds  Soil_Crop_Sandy_Paddy  \
# 0                    False                      False                  False
# 1                     True                      False                  False
# 2                     True                      False                  False
# 3                    False                      False                  False
# 4                    False                      False                  False
#
#    Soil_Crop_Sandy_Pulses  Soil_Crop_Sandy_Sugarcane  Soil_Crop_Sandy_Tobacco  \
# 0                   False                      False                    False
# 1                   False                      False                    False
# 2                   False                      False                    False
# 3                   False                      False                    False
# 4                   False                      False                    False
#
#    Soil_Crop_Sandy_Wheat  class
# 0                  False      0
# 1                  False      0
# 2                  False      1
# 3                  False      2
# 4                  False      3
#
# [5 rows x 79 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            750000 non-null  int64
#  1   Temparature                   750000 non-null  int64
#  2   Humidity                      750000 non-null  int64
#  3   Moisture                      750000 non-null  int64
#  4   Nitrogen                      750000 non-null  int64
#  5   Potassium                     750000 non-null  int64
#  6   Phosphorous                   750000 non-null  int64
#  7   Soil Type_Black               750000 non-null  bool
#  8   Soil Type_Clayey              750000 non-null  bool
#  9   Soil Type_Loamy               750000 non-null  bool
#  10  Soil Type_Red                 750000 non-null  bool
#  11  Soil Type_Sandy               750000 non-null  bool
#  12  Crop Type_Barley              750000 non-null  bool
#  13  Crop Type_Cotton              750000 non-null  bool
#  14  Crop Type_Ground Nuts         750000 non-null  bool
#  15  Crop Type_Maize               750000 non-null  bool
#  16  Crop Type_Millets             750000 non-null  bool
#  17  Crop Type_Oil seeds           750000 non-null  bool
#  18  Crop Type_Paddy               750000 non-null  bool
#  19  Crop Type_Pulses              750000 non-null  bool
#  20  Crop Type_Sugarcane           750000 non-null  bool
#  21  Crop Type_Tobacco             750000 non-null  bool
#  22  Crop Type_Wheat               750000 non-null  bool
#  23  Soil_Crop_Black_Barley        750000 non-null  bool
#  24  Soil_Crop_Black_Cotton        750000 non-null  bool
#  25  Soil_Crop_Black_Ground Nuts   750000 non-null  bool
#  26  Soil_Crop_Black_Maize         750000 non-null  bool
#  27  Soil_Crop_Black_Millets       750000 non-null  bool
#  28  Soil_Crop_Black_Oil seeds     750000 non-null  bool
#  29  Soil_Crop_Black_Paddy         750000 non-null  bool
#  30  Soil_Crop_Black_Pulses        750000 non-null  bool
#  31  Soil_Crop_Black_Sugarcane     750000 non-null  bool
#  32  Soil_Crop_Black_Tobacco       750000 non-null  bool
#  33  Soil_Crop_Black_Wheat         750000 non-null  bool
#  34  Soil_Crop_Clayey_Barley       750000 non-null  bool
#  35  Soil_Crop_Clayey_Cotton       750000 non-null  bool
#  36  Soil_Crop_Clayey_Ground Nuts  750000 non-null  bool
#  37  Soil_Crop_Clayey_Maize        750000 non-null  bool
#  38  Soil_Crop_Clayey_Millets      750000 non-null  bool
#  39  Soil_Crop_Clayey_Oil seeds    750000 non-null  bool
#  40  Soil_Crop_Clayey_Paddy        750000 non-null  bool
#  41  Soil_Crop_Clayey_Pulses       750000 non-null  bool
#  42  Soil_Crop_Clayey_Sugarcane    750000 non-null  bool
#  43  Soil_Crop_Clayey_Tobacco      750000 non-null  bool
#  44  Soil_Crop_Clayey_Wheat        750000 non-null  bool
#  45  Soil_Crop_Loamy_Barley        750000 non-null  bool
#  46  Soil_Crop_Loamy_Cotton        750000 non-null  bool
#  47  Soil_Crop_Loamy_Ground Nuts   750000 non-null  bool
#  48  Soil_Crop_Loamy_Maize         750000 non-null  bool
#  49  Soil_Crop_Loamy_Millets       750000 non-null  bool
#  50  Soil_Crop_Loamy_Oil seeds     750000 non-null  bool
#  51  Soil_Crop_Loamy_Paddy         750000 non-null  bool
#  52  Soil_Crop_Loamy_Pulses        750000 non-null  bool
#  53  Soil_Crop_Loamy_Sugarcane     750000 non-null  bool
#  54  Soil_Crop_Loamy_Tobacco       750000 non-null  bool
#  55  Soil_Crop_Loamy_Wheat         750000 non-null  bool
#  56  Soil_Crop_Red_Barley          750000 non-null  bool
#  57  Soil_Crop_Red_Cotton          750000 non-null  bool
#  58  Soil_Crop_Red_Ground Nuts     750000 non-null  bool
#  59  Soil_Crop_Red_Maize           750000 non-null  bool
#  60  Soil_Crop_Red_Millets         750000 non-null  bool
#  61  Soil_Crop_Red_Oil seeds       750000 non-null  bool
#  62  Soil_Crop_Red_Paddy           750000 non-null  bool
#  63  Soil_Crop_Red_Pulses          750000 non-null  bool
#  64  Soil_Crop_Red_Sugarcane       750000 non-null  bool
#  65  Soil_Crop_Red_Tobacco         750000 non-null  bool
#  66  Soil_Crop_Red_Wheat           750000 non-null  bool
#  67  Soil_Crop_Sandy_Barley        750000 non-null  bool
#  68  Soil_Crop_Sandy_Cotton        750000 non-null  bool
#  69  Soil_Crop_Sandy_Ground Nuts   750000 non-null  bool
#  70  Soil_Crop_Sandy_Maize         750000 non-null  bool
#  71  Soil_Crop_Sandy_Millets       750000 non-null  bool
#  72  Soil_Crop_Sandy_Oil seeds     750000 non-null  bool
#  73  Soil_Crop_Sandy_Paddy         750000 non-null  bool
#  74  Soil_Crop_Sandy_Pulses        750000 non-null  bool
#  75  Soil_Crop_Sandy_Sugarcane     750000 non-null  bool
#  76  Soil_Crop_Sandy_Tobacco       750000 non-null  bool
#  77  Soil_Crop_Sandy_Wheat         750000 non-null  bool
#  78  class                         750000 non-null  int64
# dtypes: bool(71), int64(8)
# memory usage: 96.6 MB
