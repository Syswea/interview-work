# %%
import numpy as np
import pandas as pd

# %%
# define files path
train_path = "./train.csv"
test_path = "./test.csv"

# %%
# read csv file
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
# review train file
print(f"head of train_df:")
display(train_df.head())

print(f"head of test_df:")
display(test_df.head())


print(f"shape of train_df:{train_df.shape}")
print(f"info of train_df:")
train_df.info()
# Out:
# head of train_df:
#    id  Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0   0           37        70        36    Clayey  Sugarcane        36
# 1   1           27        69        65     Sandy    Millets        30
# 2   2           29        63        32     Sandy    Millets        24
# 3   3           35        62        54     Sandy     Barley        39
# 4   4           35        58        43       Red      Paddy        37
#
#    Potassium  Phosphorous Fertilizer Name
# 0          4            5           28-28
# 1          6           18           28-28
# 2         12           16        17-17-17
# 3         12            4        10-26-26
# 4          2           16             DAP
# head of test_df:
#        id  Temparature  Humidity  Moisture Soil Type    Crop Type  Nitrogen  \
# 0  750000           31        70        52     Sandy        Wheat        34
# 1  750001           27        62        45       Red    Sugarcane        30
# 2  750002           28        72        28    Clayey  Ground Nuts        14
# 3  750003           37        53        57     Black  Ground Nuts        18
# 4  750004           31        55        32       Red       Pulses        13
#
#    Potassium  Phosphorous
# 0         11           24
# 1         14           15
# 2         15            4
# 3         17           36
# 4         19           14
# shape of train_df:(750000, 10)
# info of train_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               750000 non-null  int64
#  1   Temparature      750000 non-null  int64
#  2   Humidity         750000 non-null  int64
#  3   Moisture         750000 non-null  int64
#  4   Soil Type        750000 non-null  object
#  5   Crop Type        750000 non-null  object
#  6   Nitrogen         750000 non-null  int64
#  7   Potassium        750000 non-null  int64
#  8   Phosphorous      750000 non-null  int64
#  9   Fertilizer Name  750000 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 57.2+ MB

# %%
# remove id
train_df.drop(columns=['id'], inplace=True)
test_ids = test_df['id']
test_df.drop(columns=['id'], inplace=True)

print(f"shape of train: {train_df.shape}")
print(f"shape of test: {test_df.shape}")
print(f"columns names: {train_df.columns[:].tolist()}")
# Out:
# shape of train: (750000, 9)
# shape of test: (250000, 8)
# columns names: ['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type', 'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name']

# %%
def apply_sr_features(df):
    # 避免除以零
    eps = 1e-6
    
    # 1. 养分比例因子 (经典的农学指标)
    df['N_P_ratio'] = df['Nitrogen'] / (df['Phosphorous'] + eps)
    df['N_K_ratio'] = df['Nitrogen'] / (df['Potassium'] + eps)
    df['P_K_ratio'] = df['Phosphorous'] / (df['Potassium'] + eps)
    
    # 2. 环境交互因子
    df['Temp_Hum_Index'] = df['Temparature'] * df['Humidity']
    df['Moisture_Hum_Ratio'] = df['Moisture'] / (df['Humidity'] + eps)
    
    # 3. 养分总量
    df['Total_NPK'] = df['Nitrogen'] + df['Potassium'] + df['Phosphorous']
    
    # 4. 养分集中度 (SR 常用非线性组合)
    df['N_interaction'] = df['Nitrogen'] * df['Moisture']
    
    return df

# 对训练集和测试集同时应用
train_df = apply_sr_features(train_df)
test_df = apply_sr_features(test_df)

# %%
# 获取所有唯一的肥料名称
unique_fertilizers = train_df['Fertilizer Name'].unique()

print(f"共有 {len(unique_fertilizers)} 种肥料：")
print(unique_fertilizers)
# Out:
# 共有 7 种肥料：
# ['28-28' '17-17-17' '10-26-26' 'DAP' '20-20' '14-35-14' 'Urea']

# %%
# target variable y
if 'Fertilizer Name' in train_df.columns:
    
    y = train_df['Fertilizer Name'].map({'28-28':0, '17-17-17':1, '10-26-26':2, 'DAP':3, '20-20':4, '14-35-14':5, 'Urea':6})
    train_df.drop(columns=['Fertilizer Name'], inplace=True)

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

cat_cols = train_df.select_dtypes(include=['object']).columns

for col in cat_cols:
    # fill N/A
    train_df[col] = train_df[col].astype(str).fillna('missing')
    test_df[col] = test_df[col].astype(str).fillna('missing')
    
    le = LabelEncoder()

    # get all labels
    full_data = pd.concat([train_df[col], test_df[col]], axis=0)
    le.fit(full_data)
    
    train_df[col] = le.transform(train_df[col])
    test_df[col] = le.transform(test_df[col])

print("Label Encoding finish")
# Out:
# Label Encoding finish

# %%
# split train and val
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    train_df, y, test_size=0.2, random_state=42, stratify=y
)

print(f"shape of X_train: {X_train.shape}")
print(f"shape of X_val: {X_val.shape}")
# Out:
# shape of X_train: (600000, 15)
# shape of X_val: (150000, 15)

# %%
import optuna
import lightgbm as lgb
import numpy as np

# 1. 定义 MAP@3 计算函数
def mapk(actual, predicted_probs, k=3):
    """
    actual: 真实标签的数组 (n_samples,)
    predicted_probs: 模型输出的概率矩阵 (n_samples, n_classes)
    """
    scores = []
    # 获取概率最高的前 k 个索引
    top_k_indices = np.argsort(-predicted_probs, axis=1)[:, :k]
    
    for a, p in zip(actual, top_k_indices):
        score = 0.0
        for i, pred in enumerate(p):
            if pred == a:
                score = 1.0 / (i + 1)
                break
        scores.append(score)
    return np.mean(scores)

def objective_lgb(trial):
    # --- [GA 部分: 特征选择开关] ---
    all_features = X_train.columns.tolist()
    # 为每一个特征创建一个布尔开关
    selected_features = [
        col for col in all_features 
        if trial.suggest_categorical(f'use_{col}', [True, False])
    ]
    
    # 确保至少选择了一个特征，否则该 trial 无效
    if len(selected_features) == 0:
        return 0

    # 使用选中的特征子集
    X_tr_sub = X_train[selected_features]
    X_va_sub = X_val[selected_features]

    param = {
        'objective': 'multiclass',
        'num_class': 7,
        'metric': 'multi_logloss',
        'verbosity': -1,
        'device': 'gpu', # 小数据集建议用 cpu，减少数据搬运时间
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 64),
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'n_estimators': 300, # 配合早停可以使用更大的值
        'random_state': 42
    }

    model = lgb.LGBMClassifier(**param)
    
    # 关键修改：使用 Numpy 数组训练，并加入 eval_set 开启早停提速
    model.fit(
        X_tr_sub, y_train,
        eval_set=[(X_va_sub, y_val)],
        callbacks=[lgb.early_stopping(stopping_rounds=20, verbose=False)]
    )
    
    probs = model.predict_proba(X_va_sub)
    score = mapk(y_val, probs, k=3)
    
    return score

# 6. 开始优化
study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lgb, n_trials=30)

print("最优参数: ", study_lgb.best_params)
print("最高 MAP@3: ", study_lgb.best_value)
# Out:
# [I 2026-01-04 13:56:36,460] A new study created in memory with name: no-name-3bed87c3-abc1-4856-98ad-5b56464e8e4f
# [I 2026-01-04 13:56:48,007] Trial 0 finished with value: 0.3011166666666667 and parameters: {'use_Temparature': False, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': True, 'use_Nitrogen': False, 'use_Potassium': True, 'use_Phosphorous': False, 'use_N_P_ratio': True, 'use_N_K_ratio': True, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': True, 'use_N_interaction': False, 'learning_rate': 0.012447092616141771, 'num_leaves': 31, 'max_depth': 4}. Best is trial 0 with value: 0.3011166666666667.
# [I 2026-01-04 13:57:09,048] Trial 1 finished with value: 0.3006111111111111 and parameters: {'use_Temparature': True, 'use_Humidity': False, 'use_Moisture': False, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': False, 'use_Potassium': False, 'use_Phosphorous': True, 'use_N_P_ratio': True, 'use_N_K_ratio': True, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': True, 'use_N_interaction': True, 'learning_rate': 0.012027943902659991, 'num_leaves': 36, 'max_depth': 7}. Best is trial 0 with value: 0.3011166666666667.
# [I 2026-01-04 13:57:33,703] Trial 2 finished with value: 0.3024166666666667 and parameters: {'use_Temparature': True, 'use_Humidity': False, 'use_Moisture': False, 'use_Soil Type': True, 'use_Crop Type': True, 'use_Nitrogen': False, 'use_Potassium': True, 'use_Phosphorous': False, 'use_N_P_ratio': True, 'use_N_K_ratio': False, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': True, 'use_N_interaction': True, 'learning_rate': 0.020340011999930234, 'num_leaves': 56, 'max_depth': 6}. Best is trial 2 with value: 0.3024166666666667.
# [I 2026-01-04 13:57:41,689] Trial 3 finished with value: 0.2875733333333333 and parameters: {'use_Temparature': False, 'use_Humidity': False, 'use_Moisture': False, 'use_Soil Type': False, 'use_Crop Type': False, 'use_Nitrogen': False, 'use_Potassium': False, 'use_Phosphorous': False, 'use_N_P_ratio': False, 'use_N_K_ratio': True, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.02262116817632357, 'num_leaves': 54, 'max_depth': 3}. Best is trial 2 with value: 0.3024166666666667.
# [I 2026-01-04 13:57:50,390] Trial 4 finished with value: 0.30345 and parameters: {'use_Temparature': True, 'use_Humidity': False, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': True, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': True, 'use_N_interaction': False, 'learning_rate': 0.023127597002183947, 'num_leaves': 43, 'max_depth': 3}. Best is trial 4 with value: 0.30345.
# [I 2026-01-04 13:57:58,861] Trial 5 finished with value: 0.3020755555555556 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': False, 'use_Crop Type': False, 'use_Nitrogen': False, 'use_Potassium': False, 'use_Phosphorous': True, 'use_N_P_ratio': True, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': True, 'use_N_interaction': False, 'learning_rate': 0.03384320782943409, 'num_leaves': 33, 'max_depth': 3}. Best is trial 4 with value: 0.30345.
# [I 2026-01-04 13:58:13,729] Trial 6 finished with value: 0.2995355555555555 and parameters: {'use_Temparature': False, 'use_Humidity': False, 'use_Moisture': False, 'use_Soil Type': False, 'use_Crop Type': True, 'use_Nitrogen': False, 'use_Potassium': True, 'use_Phosphorous': False, 'use_N_P_ratio': False, 'use_N_K_ratio': True, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': True, 'use_N_interaction': False, 'learning_rate': 0.03792839897493358, 'num_leaves': 51, 'max_depth': 5}. Best is trial 4 with value: 0.30345.
# [I 2026-01-04 13:58:23,139] Trial 7 finished with value: 0.3105177777777778 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': False, 'learning_rate': 0.05667561075479326, 'num_leaves': 63, 'max_depth': 3}. Best is trial 7 with value: 0.3105177777777778.
# [I 2026-01-04 13:58:43,861] Trial 8 finished with value: 0.29464444444444443 and parameters: {'use_Temparature': True, 'use_Humidity': False, 'use_Moisture': False, 'use_Soil Type': False, 'use_Crop Type': True, 'use_Nitrogen': False, 'use_Potassium': False, 'use_Phosphorous': False, 'use_N_P_ratio': True, 'use_N_K_ratio': False, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': True, 'use_N_interaction': False, 'learning_rate': 0.012858228313777316, 'num_leaves': 48, 'max_depth': 6}. Best is trial 7 with value: 0.3105177777777778.
# [I 2026-01-04 13:58:52,948] Trial 9 finished with value: 0.30029333333333336 and parameters: {'use_Temparature': False, 'use_Humidity': False, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': True, 'use_Nitrogen': False, 'use_Potassium': False, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': True, 'use_P_K_ratio': False, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': False, 'learning_rate': 0.019210616721793035, 'num_leaves': 57, 'max_depth': 3}. Best is trial 7 with value: 0.3105177777777778.
# [I 2026-01-04 13:59:05,679] Trial 10 finished with value: 0.3176422222222222 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.07918454624012533, 'num_leaves': 20, 'max_depth': 8}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 13:59:17,974] Trial 11 finished with value: 0.3169633333333334 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.08634974654629408, 'num_leaves': 20, 'max_depth': 8}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 13:59:31,566] Trial 12 finished with value: 0.3167011111111111 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.09999655884725547, 'num_leaves': 22, 'max_depth': 8}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 13:59:44,019] Trial 13 finished with value: 0.3175711111111111 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.09870921758970512, 'num_leaves': 20, 'max_depth': 8}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 13:59:58,433] Trial 14 finished with value: 0.31756666666666666 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.06295289342517453, 'num_leaves': 26, 'max_depth': 7}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 14:00:13,061] Trial 15 finished with value: 0.31639999999999996 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.06458957226934933, 'num_leaves': 27, 'max_depth': 7}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 14:00:31,621] Trial 16 finished with value: 0.3164311111111111 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.046615259957323976, 'num_leaves': 39, 'max_depth': 8}. Best is trial 10 with value: 0.3176422222222222.
# [I 2026-01-04 14:00:45,255] Trial 17 finished with value: 0.31841111111111114 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.07839396294428316, 'num_leaves': 25, 'max_depth': 7}. Best is trial 17 with value: 0.31841111111111114.
# [I 2026-01-04 14:00:58,904] Trial 18 finished with value: 0.3123766666666667 and parameters: {'use_Temparature': False, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': False, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.07691542868282902, 'num_leaves': 26, 'max_depth': 7}. Best is trial 17 with value: 0.31841111111111114.
# [I 2026-01-04 14:01:14,769] Trial 19 finished with value: 0.3167711111111111 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.04620452181110555, 'num_leaves': 29, 'max_depth': 6}. Best is trial 17 with value: 0.31841111111111114.
# [I 2026-01-04 14:01:30,998] Trial 20 finished with value: 0.31946777777777774 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.07391266487675394, 'num_leaves': 44, 'max_depth': 5}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:01:46,552] Trial 21 finished with value: 0.31944333333333336 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.0760452999890038, 'num_leaves': 45, 'max_depth': 5}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:02:02,197] Trial 22 finished with value: 0.31758333333333333 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.05381878013629816, 'num_leaves': 45, 'max_depth': 5}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:02:13,720] Trial 23 finished with value: 0.3165722222222222 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.07081805891215277, 'num_leaves': 40, 'max_depth': 4}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:02:29,811] Trial 24 finished with value: 0.3170422222222222 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.04526706211719042, 'num_leaves': 47, 'max_depth': 5}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:02:42,021] Trial 25 finished with value: 0.3093822222222222 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.027915080123793005, 'num_leaves': 37, 'max_depth': 4}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:02:57,513] Trial 26 finished with value: 0.3083933333333334 and parameters: {'use_Temparature': False, 'use_Humidity': True, 'use_Moisture': False, 'use_Soil Type': False, 'use_Crop Type': True, 'use_Nitrogen': True, 'use_Potassium': False, 'use_Phosphorous': False, 'use_N_P_ratio': True, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.08480535119360501, 'num_leaves': 42, 'max_depth': 5}. Best is trial 20 with value: 0.31946777777777774.
# [I 2026-01-04 14:03:20,031] Trial 27 finished with value: 0.3199555555555555 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.056774011398327134, 'num_leaves': 51, 'max_depth': 6}. Best is trial 27 with value: 0.3199555555555555.
# [I 2026-01-04 14:03:43,331] Trial 28 finished with value: 0.3197577777777777 and parameters: {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.05505417275741669, 'num_leaves': 51, 'max_depth': 6}. Best is trial 27 with value: 0.3199555555555555.
# [I 2026-01-04 14:04:07,356] Trial 29 finished with value: 0.31788111111111117 and parameters: {'use_Temparature': False, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': True, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': False, 'use_N_P_ratio': True, 'use_N_K_ratio': True, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': False, 'use_Moisture_Hum_Ratio': True, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.03896356264425004, 'num_leaves': 61, 'max_depth': 6}. Best is trial 27 with value: 0.3199555555555555.
# 最优参数:  {'use_Temparature': True, 'use_Humidity': True, 'use_Moisture': True, 'use_Soil Type': True, 'use_Crop Type': False, 'use_Nitrogen': True, 'use_Potassium': True, 'use_Phosphorous': True, 'use_N_P_ratio': False, 'use_N_K_ratio': False, 'use_P_K_ratio': True, 'use_Temp_Hum_Index': True, 'use_Moisture_Hum_Ratio': False, 'use_Total_NPK': False, 'use_N_interaction': True, 'learning_rate': 0.056774011398327134, 'num_leaves': 51, 'max_depth': 6}
# 最高 MAP@3:  0.3199555555555555

# %%
import json
import numpy as np
import pandas as pd
import lightgbm as lgb

# --- 1. 从 Optuna 结果中提取被选中的特征名 ---
best_params_all = study_lgb.best_params

# 找出所有值为 True 的 'use_xxx' 参数，并还原成原始列名
selected_features = [
    k.replace('use_', '') for k, v in best_params_all.items() 
    if k.startswith('use_') and v is True
]

print(f"✅ 最终模型选中的特征 ({len(selected_features)}个):")
print(selected_features)

# --- 2. 提取真正的模型超参数 (剔除 use_ 开头的开关) ---
final_model_params = {
    k: v for k, v in best_params_all.items() 
    if not k.startswith('use_')
}
final_model_params.update({
    'objective': 'multiclass',
    'num_class': 7,
    'metric': 'multi_logloss',
    'verbosity': -1,
    'device': 'cpu'  # 最终预测阶段 CPU 足够快且稳
})

# --- 3. 准备全量训练数据 (只包含选中的特征) ---
# 假设 X 是包含所有 SR 特征的完整训练 DataFrame
X_full = pd.concat([X_train, X_val])[selected_features]
y_full = pd.concat([y_train, y_val])

# --- 4. 最终全量训练 ---
print("正在进行最终全量训练...")
final_model = lgb.LGBMClassifier(**final_model_params)
final_model.fit(X_full, y_full)

# --- 5. 对测试集进行预测 (关键：只取选中的特征) ---
print("正在生成预测结果...")
# 这里的 test_df 必须也要用 selected_features 过滤
test_df_filtered = test_df[selected_features]
probs = final_model.predict_proba(test_df_filtered)

# --- 6. 生成提交文件 ---
top3_idx = np.argsort(-probs, axis=1)[:, :3]
inv_map = {0:'28-28', 1:'17-17-17', 2:'10-26-26', 3:'DAP', 4:'20-20', 5:'14-35-14', 6:'Urea'}

final_preds = [" ".join([inv_map[idx] for idx in row]) for row in top3_idx]

submission = pd.DataFrame({
    'id': test_ids,
    'Fertilizer Name': final_preds
})

submission.to_csv('submission.csv', index=False)
print("🚀 提交文件 submission.csv 已成功生成！")
display(submission.head())
# Out:
# ✅ 最终模型选中的特征 (10个):
# ['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Nitrogen', 'Potassium', 'Phosphorous', 'P_K_ratio', 'Temp_Hum_Index', 'N_interaction']
# 正在进行最终全量训练...
# 正在生成预测结果...
# 🚀 提交文件 submission.csv 已成功生成！
#        id             Fertilizer Name
# 0  750000          14-35-14 28-28 DAP
# 1  750001     17-17-17 20-20 10-26-26
# 2  750002  10-26-26 14-35-14 17-17-17
# 3  750003      14-35-14 Urea 17-17-17
# 4  750004        20-20 28-28 10-26-26
