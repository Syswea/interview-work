# %%
import numpy as np
import pandas as pd

# %%
# define files path
train_path = "./train.csv"
test_path = "./test.csv"

# %%
# read csv file
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
# review train file
print(f"head of train_df:")
display(train_df.head())

print(f"head of test_df:")
display(test_df.head())


print(f"shape of train_df:{train_df.shape}")
print(f"info of train_df:")
train_df.info()
# Out:
# head of train_df:
#    id  Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0   0           37        70        36    Clayey  Sugarcane        36
# 1   1           27        69        65     Sandy    Millets        30
# 2   2           29        63        32     Sandy    Millets        24
# 3   3           35        62        54     Sandy     Barley        39
# 4   4           35        58        43       Red      Paddy        37
#
#    Potassium  Phosphorous Fertilizer Name
# 0          4            5           28-28
# 1          6           18           28-28
# 2         12           16        17-17-17
# 3         12            4        10-26-26
# 4          2           16             DAP
# head of test_df:
#        id  Temparature  Humidity  Moisture Soil Type    Crop Type  Nitrogen  \
# 0  750000           31        70        52     Sandy        Wheat        34
# 1  750001           27        62        45       Red    Sugarcane        30
# 2  750002           28        72        28    Clayey  Ground Nuts        14
# 3  750003           37        53        57     Black  Ground Nuts        18
# 4  750004           31        55        32       Red       Pulses        13
#
#    Potassium  Phosphorous
# 0         11           24
# 1         14           15
# 2         15            4
# 3         17           36
# 4         19           14
# shape of train_df:(750000, 10)
# info of train_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               750000 non-null  int64
#  1   Temparature      750000 non-null  int64
#  2   Humidity         750000 non-null  int64
#  3   Moisture         750000 non-null  int64
#  4   Soil Type        750000 non-null  object
#  5   Crop Type        750000 non-null  object
#  6   Nitrogen         750000 non-null  int64
#  7   Potassium        750000 non-null  int64
#  8   Phosphorous      750000 non-null  int64
#  9   Fertilizer Name  750000 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 57.2+ MB

# %%
# remove id
train_df.drop(columns=['id'], inplace=True)
test_ids = test_df['id']
test_df.drop(columns=['id'], inplace=True)

print(f"shape of train: {train_df.shape}")
print(f"shape of test: {test_df.shape}")
print(f"columns names: {train_df.columns[:].tolist()}")
# Out:
# shape of train: (750000, 9)
# shape of test: (250000, 8)
# columns names: ['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type', 'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name']

# %%
# 获取所有唯一的肥料名称
unique_fertilizers = train_df['Fertilizer Name'].unique()

print(f"共有 {len(unique_fertilizers)} 种肥料：")
print(unique_fertilizers)
# Out:
# 共有 7 种肥料：
# ['28-28' '17-17-17' '10-26-26' 'DAP' '20-20' '14-35-14' 'Urea']

# %%
# target variable y
if 'Fertilizer Name' in train_df.columns:
    
    y = train_df['Fertilizer Name'].map({'28-28':0, '17-17-17':1, '10-26-26':2, 'DAP':3, '20-20':4, '14-35-14':5, 'Urea':6})
    train_df.drop(columns=['Fertilizer Name'], inplace=True)

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

cat_cols = train_df.select_dtypes(include=['object']).columns

for col in cat_cols:
    # fill N/A
    train_df[col] = train_df[col].astype(str).fillna('missing')
    test_df[col] = test_df[col].astype(str).fillna('missing')
    
    le = LabelEncoder()

    # get all labels
    full_data = pd.concat([train_df[col], test_df[col]], axis=0)
    le.fit(full_data)
    
    train_df[col] = le.transform(train_df[col])
    test_df[col] = le.transform(test_df[col])

print("Label Encoding finish")
# Out:
# Label Encoding finish

# %%
# split train and val
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    train_df, y, test_size=0.2, random_state=42, stratify=y
)

print(f"shape of X_train: {X_train.shape}")
print(f"shape of X_val: {X_val.shape}")
# Out:
# shape of X_train: (600000, 8)
# shape of X_val: (150000, 8)

# %%
import optuna
import lightgbm as lgb
import numpy as np

# 1. 定义 MAP@3 计算函数
def mapk(actual, predicted_probs, k=3):
    """
    actual: 真实标签的数组 (n_samples,)
    predicted_probs: 模型输出的概率矩阵 (n_samples, n_classes)
    """
    scores = []
    # 获取概率最高的前 k 个索引
    top_k_indices = np.argsort(-predicted_probs, axis=1)[:, :k]
    
    for a, p in zip(actual, top_k_indices):
        score = 0.0
        for i, pred in enumerate(p):
            if pred == a:
                score = 1.0 / (i + 1)
                break
        scores.append(score)
    return np.mean(scores)

def objective_lgb(trial):
    # 2. 修改参数搜索空间为多分类
    param = {
        'objective': 'multiclass',
        'num_class': 7,  # 你的肥料种类总数
        'metric': 'multi_logloss',
        'verbosity': -1,
        'device': 'gpu', # 如果没有 GPU 请改为 cpu
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 64),
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'n_estimators': 200,
        'random_state': 42
    }

    # 如果数据集很大，也可以只用一组简单的 train_test_split
    model = lgb.LGBMClassifier(**param)
    
    # 假设使用 X_train, y_train 进行简单的验证
    model.fit(X_train, y_train)
    
    # 4. 获取概率矩阵
    probs = model.predict_proba(X_val)
    
    # 5. 计算 MAP@3
    score = mapk(y_val, probs, k=3)
    
    return score

# 6. 开始优化
study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lgb, n_trials=30)

print("最优参数: ", study_lgb.best_params)
print("最高 MAP@3: ", study_lgb.best_value)
# Out:
# [I 2026-01-04 13:34:37,312] A new study created in memory with name: no-name-9a3e0592-6fc8-4ab1-ba66-ab4bc7102f39
# [I 2026-01-04 13:34:43,450] Trial 0 finished with value: 0.3126311111111111 and parameters: {'learning_rate': 0.01804786480710216, 'num_leaves': 25, 'max_depth': 7, 'min_child_samples': 54, 'subsample': 0.7939291707649618, 'colsample_bytree': 0.81749176443932}. Best is trial 0 with value: 0.3126311111111111.
# [I 2026-01-04 13:34:50,781] Trial 1 finished with value: 0.31543666666666664 and parameters: {'learning_rate': 0.015133898829096066, 'num_leaves': 58, 'max_depth': 7, 'min_child_samples': 63, 'subsample': 0.7848484304439571, 'colsample_bytree': 0.726267706580765}. Best is trial 1 with value: 0.31543666666666664.
# [I 2026-01-04 13:34:55,906] Trial 2 finished with value: 0.3017699999999999 and parameters: {'learning_rate': 0.012920549751380236, 'num_leaves': 24, 'max_depth': 4, 'min_child_samples': 40, 'subsample': 0.8457703432954939, 'colsample_bytree': 0.8571344502966183}. Best is trial 1 with value: 0.31543666666666664.
# [I 2026-01-04 13:35:00,089] Trial 3 finished with value: 0.31084666666666666 and parameters: {'learning_rate': 0.05668388395458201, 'num_leaves': 41, 'max_depth': 3, 'min_child_samples': 14, 'subsample': 0.6438396944056153, 'colsample_bytree': 0.9484921277967394}. Best is trial 1 with value: 0.31543666666666664.
# [I 2026-01-04 13:35:05,784] Trial 4 finished with value: 0.3153055555555556 and parameters: {'learning_rate': 0.027223066743276722, 'num_leaves': 21, 'max_depth': 6, 'min_child_samples': 11, 'subsample': 0.5333932959266405, 'colsample_bytree': 0.7507672455743475}. Best is trial 1 with value: 0.31543666666666664.
# [I 2026-01-04 13:35:09,984] Trial 5 finished with value: 0.3036766666666666 and parameters: {'learning_rate': 0.026140465343001223, 'num_leaves': 32, 'max_depth': 3, 'min_child_samples': 54, 'subsample': 0.6562825649860965, 'colsample_bytree': 0.6600971940749496}. Best is trial 1 with value: 0.31543666666666664.
# [I 2026-01-04 13:35:17,732] Trial 6 finished with value: 0.3215411111111111 and parameters: {'learning_rate': 0.0208294498186794, 'num_leaves': 62, 'max_depth': 8, 'min_child_samples': 44, 'subsample': 0.7408496986441473, 'colsample_bytree': 0.6416252433874409}. Best is trial 6 with value: 0.3215411111111111.
# [I 2026-01-04 13:35:23,392] Trial 7 finished with value: 0.3157555555555555 and parameters: {'learning_rate': 0.028483939685744464, 'num_leaves': 21, 'max_depth': 6, 'min_child_samples': 43, 'subsample': 0.6788498183960363, 'colsample_bytree': 0.7646179188737594}. Best is trial 6 with value: 0.3215411111111111.
# [I 2026-01-04 13:35:29,744] Trial 8 finished with value: 0.3271755555555555 and parameters: {'learning_rate': 0.06955913400382435, 'num_leaves': 53, 'max_depth': 6, 'min_child_samples': 15, 'subsample': 0.8670993273243675, 'colsample_bytree': 0.8969612277135658}. Best is trial 8 with value: 0.3271755555555555.
# [I 2026-01-04 13:35:33,991] Trial 9 finished with value: 0.30261999999999994 and parameters: {'learning_rate': 0.022735415139634327, 'num_leaves': 54, 'max_depth': 3, 'min_child_samples': 49, 'subsample': 0.6713574264038249, 'colsample_bytree': 0.6703611474808644}. Best is trial 8 with value: 0.3271755555555555.
# [I 2026-01-04 13:35:39,587] Trial 10 finished with value: 0.3267333333333333 and parameters: {'learning_rate': 0.09398603634693362, 'num_leaves': 49, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.9533047199240019, 'colsample_bytree': 0.9631313177785604}. Best is trial 8 with value: 0.3271755555555555.
# [I 2026-01-04 13:35:45,434] Trial 11 finished with value: 0.32713333333333333 and parameters: {'learning_rate': 0.09605764339027989, 'num_leaves': 48, 'max_depth': 5, 'min_child_samples': 100, 'subsample': 0.998550300130268, 'colsample_bytree': 0.9406548211706788}. Best is trial 8 with value: 0.3271755555555555.
# [I 2026-01-04 13:35:51,454] Trial 12 finished with value: 0.32788333333333336 and parameters: {'learning_rate': 0.09749571045141842, 'num_leaves': 45, 'max_depth': 5, 'min_child_samples': 99, 'subsample': 0.9975068608375153, 'colsample_bytree': 0.5226094166287213}. Best is trial 12 with value: 0.32788333333333336.
# [I 2026-01-04 13:35:56,949] Trial 13 finished with value: 0.3228333333333333 and parameters: {'learning_rate': 0.05817724699662691, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 26, 'subsample': 0.9005617945890413, 'colsample_bytree': 0.5167997233183342}. Best is trial 12 with value: 0.32788333333333336.
# [I 2026-01-04 13:36:01,827] Trial 14 finished with value: 0.31712444444444443 and parameters: {'learning_rate': 0.05624235775846083, 'num_leaves': 47, 'max_depth': 4, 'min_child_samples': 73, 'subsample': 0.8972102262990074, 'colsample_bytree': 0.572948890660864}. Best is trial 12 with value: 0.32788333333333336.
# [I 2026-01-04 13:36:08,226] Trial 15 finished with value: 0.32197333333333333 and parameters: {'learning_rate': 0.04208980651737216, 'num_leaves': 35, 'max_depth': 7, 'min_child_samples': 29, 'subsample': 0.9945335665011806, 'colsample_bytree': 0.8584629807644166}. Best is trial 12 with value: 0.32788333333333336.
# [I 2026-01-04 13:36:15,022] Trial 16 finished with value: 0.3307488888888889 and parameters: {'learning_rate': 0.07638099649830936, 'num_leaves': 54, 'max_depth': 6, 'min_child_samples': 99, 'subsample': 0.8933147986199076, 'colsample_bytree': 0.5193528155726511}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:19,826] Trial 17 finished with value: 0.3141322222222222 and parameters: {'learning_rate': 0.040553560901897365, 'num_leaves': 64, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.9462700263630983, 'colsample_bytree': 0.5139446182009784}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:25,837] Trial 18 finished with value: 0.329188888888889 and parameters: {'learning_rate': 0.0754022686805643, 'num_leaves': 44, 'max_depth': 8, 'min_child_samples': 82, 'subsample': 0.9354854333265434, 'colsample_bytree': 0.5765724257538801}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:32,866] Trial 19 finished with value: 0.32595222222222225 and parameters: {'learning_rate': 0.039780741761402345, 'num_leaves': 56, 'max_depth': 8, 'min_child_samples': 82, 'subsample': 0.8294383271508317, 'colsample_bytree': 0.5892835849882586}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:38,924] Trial 20 finished with value: 0.32774333333333333 and parameters: {'learning_rate': 0.07466619905848837, 'num_leaves': 36, 'max_depth': 8, 'min_child_samples': 85, 'subsample': 0.9345365675006888, 'colsample_bytree': 0.5861336227740136}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:45,126] Trial 21 finished with value: 0.33015777777777777 and parameters: {'learning_rate': 0.0784758278001339, 'num_leaves': 45, 'max_depth': 7, 'min_child_samples': 93, 'subsample': 0.9092541963717943, 'colsample_bytree': 0.5011235455488317}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:51,376] Trial 22 finished with value: 0.32901555555555556 and parameters: {'learning_rate': 0.07630995048196644, 'num_leaves': 44, 'max_depth': 7, 'min_child_samples': 72, 'subsample': 0.8923489695955379, 'colsample_bytree': 0.5671117347181723}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:36:58,309] Trial 23 finished with value: 0.32787444444444436 and parameters: {'learning_rate': 0.04936382620864725, 'num_leaves': 49, 'max_depth': 8, 'min_child_samples': 92, 'subsample': 0.9353113341843395, 'colsample_bytree': 0.5009652261404685}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:37:04,724] Trial 24 finished with value: 0.33027 and parameters: {'learning_rate': 0.0699236631460394, 'num_leaves': 51, 'max_depth': 7, 'min_child_samples': 76, 'subsample': 0.8011215597720611, 'colsample_bytree': 0.5489480987871982}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:37:11,702] Trial 25 finished with value: 0.3229455555555556 and parameters: {'learning_rate': 0.03450201478895818, 'num_leaves': 59, 'max_depth': 6, 'min_child_samples': 71, 'subsample': 0.8141085538376582, 'colsample_bytree': 0.6227906110095358}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:37:18,420] Trial 26 finished with value: 0.32807555555555556 and parameters: {'learning_rate': 0.06315504274653552, 'num_leaves': 52, 'max_depth': 7, 'min_child_samples': 90, 'subsample': 0.7496078736100593, 'colsample_bytree': 0.7011215522501069}. Best is trial 16 with value: 0.3307488888888889.
# [I 2026-01-04 13:37:24,739] Trial 27 finished with value: 0.33081444444444447 and parameters: {'learning_rate': 0.08515626826818463, 'num_leaves': 52, 'max_depth': 7, 'min_child_samples': 77, 'subsample': 0.8558532403887464, 'colsample_bytree': 0.5427909705299875}. Best is trial 27 with value: 0.33081444444444447.
# [I 2026-01-04 13:37:31,834] Trial 28 finished with value: 0.31036111111111114 and parameters: {'learning_rate': 0.010216059284390844, 'num_leaves': 51, 'max_depth': 6, 'min_child_samples': 76, 'subsample': 0.865130524116328, 'colsample_bytree': 0.5487000018647935}. Best is trial 27 with value: 0.33081444444444447.
# [I 2026-01-04 13:37:38,395] Trial 29 finished with value: 0.3325088888888889 and parameters: {'learning_rate': 0.08451814387217108, 'num_leaves': 60, 'max_depth': 7, 'min_child_samples': 61, 'subsample': 0.780659762996841, 'colsample_bytree': 0.6080344144153701}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:37:45,511] Trial 30 finished with value: 0.32740888888888886 and parameters: {'learning_rate': 0.04915759505610693, 'num_leaves': 60, 'max_depth': 7, 'min_child_samples': 66, 'subsample': 0.705785716269708, 'colsample_bytree': 0.6104936323675237}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:37:51,835] Trial 31 finished with value: 0.3322800000000001 and parameters: {'learning_rate': 0.08439218636441341, 'num_leaves': 56, 'max_depth': 7, 'min_child_samples': 61, 'subsample': 0.8101775928084448, 'colsample_bytree': 0.542755982447928}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:37:58,050] Trial 32 finished with value: 0.331601111111111 and parameters: {'learning_rate': 0.08641612463843015, 'num_leaves': 56, 'max_depth': 7, 'min_child_samples': 62, 'subsample': 0.7775130216435187, 'colsample_bytree': 0.5425613007976172}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:04,371] Trial 33 finished with value: 0.33159222222222223 and parameters: {'learning_rate': 0.08928625518204002, 'num_leaves': 57, 'max_depth': 7, 'min_child_samples': 63, 'subsample': 0.7770369061293977, 'colsample_bytree': 0.6230602045042556}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:10,686] Trial 34 finished with value: 0.33007666666666663 and parameters: {'learning_rate': 0.08774742590897691, 'num_leaves': 56, 'max_depth': 7, 'min_child_samples': 64, 'subsample': 0.7821148363620509, 'colsample_bytree': 0.7035360793048467}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:17,439] Trial 35 finished with value: 0.33032666666666666 and parameters: {'learning_rate': 0.061953196475869644, 'num_leaves': 64, 'max_depth': 8, 'min_child_samples': 57, 'subsample': 0.7724498334440685, 'colsample_bytree': 0.6191024152031019}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:24,767] Trial 36 finished with value: 0.31605888888888883 and parameters: {'learning_rate': 0.016173940733957382, 'num_leaves': 57, 'max_depth': 7, 'min_child_samples': 59, 'subsample': 0.6005226766814042, 'colsample_bytree': 0.7713693997762033}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:31,337] Trial 37 finished with value: 0.33139888888888885 and parameters: {'learning_rate': 0.08645930719518045, 'num_leaves': 61, 'max_depth': 6, 'min_child_samples': 48, 'subsample': 0.7180831287097931, 'colsample_bytree': 0.648622224080273}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:37,116] Trial 38 finished with value: 0.3235977777777777 and parameters: {'learning_rate': 0.04775220173753233, 'num_leaves': 29, 'max_depth': 8, 'min_child_samples': 60, 'subsample': 0.7631151772019471, 'colsample_bytree': 0.6054972817551727}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:43,727] Trial 39 finished with value: 0.32964 and parameters: {'learning_rate': 0.06458412429232707, 'num_leaves': 58, 'max_depth': 7, 'min_child_samples': 37, 'subsample': 0.7294032938421048, 'colsample_bytree': 0.6799212759738662}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:50,569] Trial 40 finished with value: 0.33037333333333335 and parameters: {'learning_rate': 0.0853483154917947, 'num_leaves': 62, 'max_depth': 6, 'min_child_samples': 53, 'subsample': 0.6243421917341179, 'colsample_bytree': 0.735688714113365}. Best is trial 29 with value: 0.3325088888888889.
# [I 2026-01-04 13:38:57,328] Trial 41 finished with value: 0.33268888888888887 and parameters: {'learning_rate': 0.09829263879783082, 'num_leaves': 61, 'max_depth': 6, 'min_child_samples': 47, 'subsample': 0.7135136419518686, 'colsample_bytree': 0.6409854466084727}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:03,413] Trial 42 finished with value: 0.33157666666666674 and parameters: {'learning_rate': 0.09802915482899581, 'num_leaves': 55, 'max_depth': 7, 'min_child_samples': 67, 'subsample': 0.7045324390287069, 'colsample_bytree': 0.6433884995506546}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:09,940] Trial 43 finished with value: 0.33071777777777783 and parameters: {'learning_rate': 0.08239165077066697, 'num_leaves': 59, 'max_depth': 6, 'min_child_samples': 48, 'subsample': 0.822807380907061, 'colsample_bytree': 0.6250476931129716}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:16,412] Trial 44 finished with value: 0.32889666666666667 and parameters: {'learning_rate': 0.06892555138714228, 'num_leaves': 62, 'max_depth': 7, 'min_child_samples': 37, 'subsample': 0.7960936054679857, 'colsample_bytree': 0.792975594354705}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:22,648] Trial 45 finished with value: 0.33252111111111116 and parameters: {'learning_rate': 0.09907665491888734, 'num_leaves': 58, 'max_depth': 6, 'min_child_samples': 55, 'subsample': 0.6816662009927258, 'colsample_bytree': 0.5484850568266333}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:28,073] Trial 46 finished with value: 0.3278977777777778 and parameters: {'learning_rate': 0.09883992318110389, 'num_leaves': 61, 'max_depth': 5, 'min_child_samples': 52, 'subsample': 0.6863732188499133, 'colsample_bytree': 0.5407947371256135}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:34,494] Trial 47 finished with value: 0.3300366666666667 and parameters: {'learning_rate': 0.07060332301237715, 'num_leaves': 64, 'max_depth': 6, 'min_child_samples': 44, 'subsample': 0.6435518180526936, 'colsample_bytree': 0.5590650758418108}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:40,993] Trial 48 finished with value: 0.3278877777777778 and parameters: {'learning_rate': 0.056634562740895435, 'num_leaves': 54, 'max_depth': 6, 'min_child_samples': 56, 'subsample': 0.5497828139158227, 'colsample_bytree': 0.5979590957440546}. Best is trial 41 with value: 0.33268888888888887.
# [I 2026-01-04 13:39:46,521] Trial 49 finished with value: 0.3135088888888888 and parameters: {'learning_rate': 0.022367259953522425, 'num_leaves': 60, 'max_depth': 5, 'min_child_samples': 31, 'subsample': 0.7311148052509836, 'colsample_bytree': 0.5296580455821979}. Best is trial 41 with value: 0.33268888888888887.
# 最优参数:  {'learning_rate': 0.09829263879783082, 'num_leaves': 61, 'max_depth': 6, 'min_child_samples': 47, 'subsample': 0.7135136419518686, 'colsample_bytree': 0.6409854466084727}
# 最高 MAP@3:  0.33268888888888887

# %%
import json

# 1. 获取最优参数字典
best_lgb_params = study_lgb.best_params

# 2. 建议手动加入一些非搜索的固定参数，确保文件完整
best_lgb_params.update({
    'objective': 'multiclass',
    'num_class': 7,  # 你的肥料种类总数
    'metric': 'multi_logloss',
    'verbosity': -1
})

# 3. 写入文件
with open('best_lgb_params.json', 'w') as f:
    json.dump(best_lgb_params, f, indent=4)

print("LightGBM 参数已保存至 best_lgb_params.json")
# Out:
# LightGBM 参数已保存至 best_lgb_params.json

# %%
# --- A. 加载之前保存的最优参数 ---
with open('best_lgb_params.json', 'r') as f:
    final_params = json.load(f)

# --- B. 准备全量训练数据 ---
# 使用合并后的训练集和验证集进行最后一次训练，最大化利用数据
X_full = pd.concat([X_train, X_val])
y_full = pd.concat([y_train, y_val])

print("正在使用全量数据进行最终训练...")
final_model = lgb.LGBMClassifier(**final_params)
final_model.fit(X_full, y_full)

# --- C. 对测试集进行预测 ---
# 获取概率矩阵 [n_samples, 7]
probs = final_model.predict_proba(test_df)

# 获取概率最高的前 3 个索引
top3_idx = np.argsort(-probs, axis=1)[:, :3]

# --- D. 映射回肥料名称字符串 ---
# 创建索引到名称的逆向字典
# 注意：这里的映射顺序必须和你之前映射 y 时的字典完全一致
inv_map = {0:'28-28', 1:'17-17-17', 2:'10-26-26', 3:'DAP', 4:'20-20', 5:'14-35-14', 6:'Urea'}

final_preds = []
for row in top3_idx:
    # 将 3 个预测值拼成空格分隔的字符串
    labels = [inv_map[idx] for idx in row]
    final_preds.append(" ".join(labels))

# --- E. 生成提交文件 ---
submission = pd.DataFrame({
    'id': test_ids,
    'Fertilizer Name': final_preds
})

submission.to_csv('submission.csv', index=False)
print("恭喜！提交文件 submission.csv 已生成。")
display(submission.head())
# Out:
# 正在使用全量数据进行最终训练...
# 恭喜！提交文件 submission.csv 已生成。
#        id             Fertilizer Name
# 0  750000             28-28 DAP 20-20
# 1  750001     17-17-17 20-20 10-26-26
# 2  750002     20-20 14-35-14 10-26-26
# 3  750003  14-35-14 17-17-17 10-26-26
# 4  750004     20-20 10-26-26 17-17-17
